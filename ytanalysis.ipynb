# %%
# !pip install isodate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: isodate in /home/92b0598e-a622-439e-9a02-6cd5f26968be/.local/lib/python3.10/site-packages (0.6.1)
# Requirement already satisfied: six in /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages (from isodate) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import isodate

# %% [markdown]
# **Importing Trending YouTube Videos Data, according to July-August 2024**

# %%
df = pd.read_csv('trending_videos.csv')
df1 = pd.read_csv('category.csv')

# %%
df
# Out:
#                                                  title  \
# 0    Charli xcx - Guess featuring Billie Eilish (of...
# 1    Shelly-Ann Fraser-Pryce & Sha'Carri Richardson...
# 2    Jordan Adetunji - KEHLANI REMIX (feat. Kehlani...
# 3    Nessa Barrett - PASSENGER PRINCESS (Official M...
# 4    Houston Texans vs. Chicago Bears Highlights | ...
# ..                                                 ...
# 195  MADNESS AT YANKEE STADIUM 🏟️ Manchester City v...
# 196   RYAN REYNOLDS & HUGH JACKMAN | CHICKEN SHOP DATE
# 197  They Said They Were The Greatest Team Of All-T...
# 198                    PLAYING ROBLOX DRESS TO IMPRESS
# 199        Astro Bot DualSense Controller Reveal | PS5
#
#                                            description  \
# 0    Charli xcx - Guess featuring Billie Eilish\nSt...
# 1    The 2024 Olympics are officially getting epic....
# 2    The official video for Jordan Adetunji's “KEHL...
# 3    Listen to "PASSENGER PRINCESS": https://nessa....
# 4    Houston Texans play the Chicago Bears at Tom B...
# ..                                                 ...
# 195  Check out these highlights from AC Milan's 3-2...
# 196  Amelia meets Ryan Reynolds and Hugh Jackman fo...
# 197  Don’t miss out on all the action this week at ...
# 198  MERCHHH!!!\n\nhttps://sturnioloclothing.com\n\...
# 199  https://blog.playstation.com/2024/07/29/first-...
#
#                  published_at              channel_title  \
# 0   2024-08-01 22:00:24+00:00                 Charli xcx
# 1   2024-08-02 19:40:39+00:00  Total Running Productions
# 2   2024-08-02 14:00:06+00:00            Jordan Adetunji
# 3   2024-08-01 16:00:08+00:00              Nessa Barrett
# 4   2024-08-02 03:42:03+00:00                        NFL
# ..                        ...                        ...
# 195 2024-07-28 00:33:47+00:00                    ESPN FC
# 196 2024-07-26 16:00:05+00:00        Amelia Dimoldenberg
# 197 2024-07-27 01:10:17+00:00             JxmyHighroller
# 198 2024-07-26 21:30:05+00:00         Sturniolo Triplets
# 199 2024-07-29 14:00:12+00:00                PlayStation
#
#                                                   tags  duration definition  \
# 0    ['charli xcx', 'billie eilish', 'guess featuri...     161.0         hd
# 1    ['shelly-ann fraser-pryce', '2024 olympics', "...     525.0         hd
# 2    ['Kehlani', 'Jordanadetunji', 'Rap', 'Drill', ...     212.0         hd
# 3    ['nessa tiktok', 'nessa barrett madhouse', 'ne...     174.0         hd
# 4    ['Chicago Bears', 'Houston Texans', 'Houston T...     361.0         hd
# ..                                                 ...       ...        ...
# 195  ['manchester city', 'man city', 'man city high...     579.0         hd
# 196                                                 []     503.0         hd
# 197  ['LeBron James', 'House of Highlights', 'ESPN'...     961.0         hd
# 198                                                 []    1662.0         hd
# 199  ['PS5', 'ASTRO BOT', 'DualSense', 'PlayStation...      29.0         hd
#
#      caption  view_count  like_count  dislike_count  favorite_count  \
# 0      False     4770613      425346              0               0
# 1      False     1356173        7589              0               0
# 2      False      557654       53491              0               0
# 3      False     1113868       43349              0               0
# 4       True      683437        9713              0               0
# ..       ...         ...         ...            ...             ...
# 195    False      474737        3854              0               0
# 196     True     3707566      161635              0               0
# 197    False     1544911       53753              0               0
# 198    False     1522315      157561              0               0
# 199     True      604268       18719              0               0
#
#      comment_count  category_id category_name duration_range  tag_count  \
# 0            25733           10        Comedy        0-5 min        517
# 1              697           17        Movies       5-10 min        280
# 2             1961           10        Comedy        0-5 min        539
# 3             2111           10        Comedy        0-5 min        445
# 4             1460           17        Movies       5-10 min         71
# ..             ...          ...           ...            ...        ...
# 195            531           17        Movies       5-10 min        467
# 196           3326           24        Family       5-10 min          2
# 197           5812           17        Movies      10-20 min        502
# 198          14084           23         Drama      20-60 min          2
# 199           1326           20      Classics        0-5 min        151
#
#      publish_hour
# 0              22
# 1              19
# 2              14
# 3              16
# 4               3
# ..            ...
# 195             0
# 196            16
# 197             1
# 198            21
# 199            14
#
# [200 rows x 18 columns]

# %% [markdown]
# **Searching for null values and Clearing them**

# %%
df.isnull().sum()
# Out:
# title             0
# description       1
# published_at      0
# channel_title     0
# tags              0
# duration          0
# definition        0
# caption           0
# view_count        0
# like_count        0
# dislike_count     0
# favorite_count    0
# comment_count     0
# category_id       0
# category_name     0
# duration_range    0
# tag_count         0
# publish_hour      0
# dtype: int64

# %%
df['description'].fillna('No Description', inplace=True)

# %%
df1.columns = ['Id','Category']
df1
# Out:
#     Id               Category
# 0    1       Film & Animation
# 1    2       Autos & Vehicles
# 2   10                  Music
# 3   15         Pets & Animals
# 4   17                 Sports
# 5   18           Short Movies
# 6   19        Travel & Events
# 7   20                 Gaming
# 8   21          Videoblogging
# 9   22         People & Blogs
# 10  23                 Comedy
# 11  24          Entertainment
# 12  25        News & Politics
# 13  26          Howto & Style
# 14  27              Education
# 15  28   Science & Technology
# 16  29  Nonprofits & Activism
# 17  30                 Movies
# 18  31        Anime/Animation
# 19  32       Action/Adventure
# 20  33               Classics
# 21  34                 Comedy
# 22  35            Documentary
# 23  36                  Drama
# 24  37                 Family
# 25  38                Foreign
# 26  39                 Horror
# 27  40         Sci-Fi/Fantasy
# 28  41               Thriller
# 29  42                 Shorts
# 30  43                  Shows
# 31  44               Trailers

# %% [markdown]
# **Assigning Categories to their respective Category_id**

# %%
def check(x):
    return df1.loc[x,'Category']

df['category_name'] = df['category_id'].apply(lambda x : check(x))
df
# Out:
#                                                  title  \
# 0    Charli xcx - Guess featuring Billie Eilish (of...
# 1    Shelly-Ann Fraser-Pryce & Sha'Carri Richardson...
# 2    Jordan Adetunji - KEHLANI REMIX (feat. Kehlani...
# 3    Nessa Barrett - PASSENGER PRINCESS (Official M...
# 4    Houston Texans vs. Chicago Bears Highlights | ...
# ..                                                 ...
# 195  MADNESS AT YANKEE STADIUM 🏟️ Manchester City v...
# 196   RYAN REYNOLDS & HUGH JACKMAN | CHICKEN SHOP DATE
# 197  They Said They Were The Greatest Team Of All-T...
# 198                    PLAYING ROBLOX DRESS TO IMPRESS
# 199        Astro Bot DualSense Controller Reveal | PS5
#
#                                            description  \
# 0    Charli xcx - Guess featuring Billie Eilish\nSt...
# 1    The 2024 Olympics are officially getting epic....
# 2    The official video for Jordan Adetunji's “KEHL...
# 3    Listen to "PASSENGER PRINCESS": https://nessa....
# 4    Houston Texans play the Chicago Bears at Tom B...
# ..                                                 ...
# 195  Check out these highlights from AC Milan's 3-2...
# 196  Amelia meets Ryan Reynolds and Hugh Jackman fo...
# 197  Don’t miss out on all the action this week at ...
# 198  MERCHHH!!!\n\nhttps://sturnioloclothing.com\n\...
# 199  https://blog.playstation.com/2024/07/29/first-...
#
#                  published_at              channel_title  \
# 0   2024-08-01 22:00:24+00:00                 Charli xcx
# 1   2024-08-02 19:40:39+00:00  Total Running Productions
# 2   2024-08-02 14:00:06+00:00            Jordan Adetunji
# 3   2024-08-01 16:00:08+00:00              Nessa Barrett
# 4   2024-08-02 03:42:03+00:00                        NFL
# ..                        ...                        ...
# 195 2024-07-28 00:33:47+00:00                    ESPN FC
# 196 2024-07-26 16:00:05+00:00        Amelia Dimoldenberg
# 197 2024-07-27 01:10:17+00:00             JxmyHighroller
# 198 2024-07-26 21:30:05+00:00         Sturniolo Triplets
# 199 2024-07-29 14:00:12+00:00                PlayStation
#
#                                                   tags  duration definition  \
# 0    ['charli xcx', 'billie eilish', 'guess featuri...     161.0         hd
# 1    ['shelly-ann fraser-pryce', '2024 olympics', "...     525.0         hd
# 2    ['Kehlani', 'Jordanadetunji', 'Rap', 'Drill', ...     212.0         hd
# 3    ['nessa tiktok', 'nessa barrett madhouse', 'ne...     174.0         hd
# 4    ['Chicago Bears', 'Houston Texans', 'Houston T...     361.0         hd
# ..                                                 ...       ...        ...
# 195  ['manchester city', 'man city', 'man city high...     579.0         hd
# 196                                                 []     503.0         hd
# 197  ['LeBron James', 'House of Highlights', 'ESPN'...     961.0         hd
# 198                                                 []    1662.0         hd
# 199  ['PS5', 'ASTRO BOT', 'DualSense', 'PlayStation...      29.0         hd
#
#      caption  view_count  like_count  dislike_count  favorite_count  \
# 0      False     4770613      425346              0               0
# 1      False     1356173        7589              0               0
# 2      False      557654       53491              0               0
# 3      False     1113868       43349              0               0
# 4       True      683437        9713              0               0
# ..       ...         ...         ...            ...             ...
# 195    False      474737        3854              0               0
# 196     True     3707566      161635              0               0
# 197    False     1544911       53753              0               0
# 198    False     1522315      157561              0               0
# 199     True      604268       18719              0               0
#
#      comment_count  category_id category_name duration_range  tag_count  \
# 0            25733           10        Comedy        0-5 min        517
# 1              697           17        Movies       5-10 min        280
# 2             1961           10        Comedy        0-5 min        539
# 3             2111           10        Comedy        0-5 min        445
# 4             1460           17        Movies       5-10 min         71
# ..             ...          ...           ...            ...        ...
# 195            531           17        Movies       5-10 min        467
# 196           3326           24        Family       5-10 min          2
# 197           5812           17        Movies      10-20 min        502
# 198          14084           23         Drama      20-60 min          2
# 199           1326           20      Classics        0-5 min        151
#
#      publish_hour
# 0              22
# 1              19
# 2              14
# 3              16
# 4               3
# ..            ...
# 195             0
# 196            16
# 197             1
# 198            21
# 199            14
#
# [200 rows x 18 columns]

# %% [markdown]
# **Highly Viewed Video in Current Trending List**

# %%
view_max = df['view_count'].max()
df.loc[df['view_count']==view_max,['title','channel_title','view_count']]
# Out:
#                                  title channel_title  view_count
# 114  50 YouTubers Fight For $1,000,000       MrBeast   210701320

# %% [markdown]
# **Highly Liked Video in Current Trending List**

# %%
like_max = df['like_count'].max()
df.loc[df['like_count']==like_max,['title','channel_title','like_count']]
# Out:
#                                  title channel_title  like_count
# 114  50 YouTubers Fight For $1,000,000       MrBeast     8207977

# %% [markdown]
# **Analyzing Trending Videos Dataset**
#
# 1. Classifying Trending Videos Category-wise

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 8))
sns.countplot(y=df['category_name'], order=df['category_name'].value_counts().index)
plt.title('Number of Trending Videos by Category')
plt.xlabel('Number of Videos')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# 2. Relation between Publish Hours and Number of Videos Posted

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

# %%
df['publish_hour'] = df['published_at'].dt.hour

plt.figure(figsize=(12, 6))
sns.countplot(x='publish_hour', data=df, palette='magma')
plt.title('Distribution of Videos by Publish Hour')
plt.xlabel('Publish Hour')
plt.ylabel('Number of Videos')
plt.show()

# %% [markdown]
# 3. Effect of Publish Hours over View Counts

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='publish_hour', y='view_count', data=df, alpha=0.6, color='teal')
plt.title('Publish Hour vs View Count')
plt.xlabel('Publish Hour')
plt.ylabel('View Count')
plt.show()

# %% [markdown]
# 4. Average Like count, View count and Comment count of each category

# %%
categ = df.groupby('category_name')[['view_count', 'like_count', 'comment_count']].mean().sort_values(by='view_count', ascending=False)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 10))

sns.barplot(y=categ.index, x=categ['view_count'].sort_values(ascending=False), ax=axes[0], palette='viridis')
axes[0].set_title('Average View Count by Category')
axes[0].set_xlabel('Average View Count')
axes[0].set_ylabel('Category')

sns.barplot(y=categ.index, x=categ['like_count'].sort_values(ascending=False), ax=axes[1], palette='viridis')
axes[1].set_title('Average Like Count by Category')
axes[1].set_xlabel('Average Like Count')

sns.barplot(y=categ.index, x=categ['comment_count'].sort_values(ascending=False), ax=axes[2], palette='viridis')
axes[2].set_title('Average Comment Count by Category')
axes[2].set_xlabel('Average Comment Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Relation between Video Length and View Counts

# %%
df['duration'] = df['duration'].apply(lambda x: isodate.parse_duration(x).total_seconds())

# %%
df['duration_range'] = pd.cut(df['duration'], bins=[0, 300, 600, 1200, 3600, 7200], labels=['0-5 min', '5-10 min', '10-20 min', '20-60 min', '60-120 min'])

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='duration', y='view_count', data=df, alpha=0.6, color='blue')
plt.title('Video Length vs View Count')
plt.xlabel('Video Length (in secs)')
plt.ylabel('View Count')
plt.show()

# %% [markdown]
# 6. Relation between Average View Count, Like Count and Duration

# %%
length_relation = df.groupby('duration_range')[['view_count', 'like_count']].mean()
# Out:
# /tmp/ipykernel_202/2059054043.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   length_relation = df.groupby('duration_range')[['view_count', 'like_count']].mean()

# %%
fig, axes = plt.subplots(1, 2, figsize=(18,8))

sns.barplot(y=length_relation.index, x=length_relation['view_count'], ax=axes[0], palette='magma')
axes[0].set_title('Average View Count by Duration Range')
axes[0].set_xlabel('Average View Count')
axes[0].set_ylabel('Duration Range')

# like count by duration range
sns.barplot(y=length_relation.index, x=length_relation['like_count'], ax=axes[1], palette='magma')
axes[1].set_title('Average Like Count by Duration Range')
axes[1].set_xlabel('Average Like Count')
axes[1].set_ylabel('')
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# Text(0, 0.5, '')

# %% [markdown]
# 7. Effects of Tags on View Count

# %%
df['tag_count'] = df['tags'].apply(len)

plt.figure(figsize=(10, 6))
sns.scatterplot(x='tag_count', y='view_count', data=df, alpha=0.6, color='cyan', edgecolor='black', linewidth=1)
plt.title('Number of Tags vs View Count')
plt.xlabel('Number of Tags')
plt.ylabel('View Count')
plt.show()
